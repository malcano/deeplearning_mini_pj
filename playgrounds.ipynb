# %% [markdown]
# # 이 파일은 PlayGround 파일입니다!
# ### 테스트 코드는 여기에서 자유롭게 테스트하세요
# #### 단, 코드가 유실되어도 책임지지 않습니다.

# %%
import pandas as pd
import json

# %%
# tmp = pd.read_json('라벨링데이터/BOHE210000025292.json')

# %%
# tmp

# %%
with open('라벨링데이터/BOHE210000025292.json') as f:
    js = json.loads(f.read()) ## json 라이브러리 이용

# %%
js.keys()
# Out:
# dict_keys(['header', 'named_entity', 'morp', 'intj'])

# %%
df_js = pd.DataFrame(js['named_entity'])

# %%
len(js['named_entity'])
# Out:
# 239

# %%
js['named_entity']
# Out:
# [{'content': [{'sentence': '이건 너무 빡세', 'labels': []}],
#   'writer': 'UgyqINko-_3MoXryhf14AaABAg',
#   'write_date': '2020-08-19',
#   'url': 'https://www.youtube.com/channel/UCTjVTRluDpKUPbpHF29DqyA',
#   'parent_url': 'https://www.youtube.com/watch?v=W8TIEJUqCbA',
#   'source_site': 'https://www.youtube.com/'},
#  {'content': [{'sentence': '아니 저거 칵테일같은데 희석할때 쓰는건데 왜 그걸 스트레이트로',
#     'labels': []}],
#   'writer': 'UgxZ87Vtf9EguPJuMTN4AaABAg',
#   'write_date': '2020-10-19',
#   'url': 'https://www.youtube.com/channel/UCTjVTRluDpKUPbpHF29DqyA',
#   'parent_url': 'https://www.youtube.com/watch?v=W8TIEJUqCbA',
#   'source_site': 'https://www.youtube.com/'},
#  {'content': [{'sentence': '왜이렇게 귀엽고 만지고싶져', 'labels': []}],
#   'writer': 'UgyZY1Usy3jDCWEto9N4AaABAg',
#   'write_date': '2020-09-19',
#   'url': 'https://www.youtube.com/channel/UCTjVTRluDpKUPbpHF29DqyA',
#   'parent_url': 'https://www.youtube.com/watch?v=W8TIEJUqCbA',
#   'source_site': 'https://www.youtube.com/'},
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   content      239 non-null    object
#  1   writer       239 non-null    object
#  2   write_date   239 non-null    object
#  3   url          239 non-null    object
#  4   parent_url   239 non-null    object
#  5   source_site  239 non-null    object
# dtypes: object(6)
# memory usage: 11.3+ KB

# %%
df
# Out:
#                                                      SJML
# header  {'identifier': '텍스트_구어체 말뭉치 구축_0000025292', 'n...
# text    [{'content': '이건 너무 빡세', 'writer': 'UgyqINko-_...

# %%
tmp = pd.read_json()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tmp = pd.read_json(df)
#
# File ~/miniconda/envs/tf-learning/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/miniconda/envs/tf-learning/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
